# %% [markdown]
# Source: http://nbviewer.jupyter.org/github/jakevdp/WhirlwindTourOfPython/blob/master/15-Preview-of-Data-Science-Tools.ipynb#Matplotlib-MatLab-style-scientific-visualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import numpy as np
x = np.linspace(0,10)
y = np.sin(x)
plt.plot(x,y);
